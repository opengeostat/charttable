# %%
import pandas as pd
import charttable as ct

df = pd.DataFrame({'A': [1., 2, 3], 'B': ['a','b','c'], 'C': ['a','b','c'], 'D': ['a','b','c']})

tabl= ct.HTMLTable(df)


tabl.addcolumn(name= "A", 
               text = df.A.values , 
               bar=[50,80,30], 
               colour=['red','green','blue'], # colour in word or hex
               overwrite=True)

tabl.addcolumn(name= "B", 
               text = ct.Leyend_cat(['c','z']).apply_colour(df.B.values), 
               bar=None, 
               colour = ct.Leyend_cat(['c','z']).apply_colour(df.B.values),
               overwrite=True)

tabl.addcolumn(name= "C", 
               text = df.C.values , 
               bar=None, 
               colour=['#FF0000','#800000','#FFFF00'], 
               overwrite=True)

tabl.display()
# Out:
#       <style type="text/css">
#         table {
#           border-collapse: collapse;
#         }
#
#         table, th, td {
#           border: 1px solid black;
#         }
#
#         /* CHART LISTS */
#         .chartlist {
#           float: left;
#           border-top: 0px solid #EEE;
#           width: 100%;
#         }
#         .chartlist .chart {
#           position: relative;
#           margin: 0 0 0 0;
#           border-bottom: 0px solid #EEE;
#         }
#         .chartlist .chart p {
#           display: block;
#           padding: 0.0em 0em 0.0em 0.0em;
#           position: relative;
#           z-index: 2;
#         }
#         .chartlist .index {
#           display: block;
#           position: absolute;
#           top: 0;
#           left: 0;
#           height: 100%;
#           text-indent: -9999px;
#           overflow: hidden;
#           line-height: 1em;
#         }
#       </style>
#     <table class='chartlist'>
#     <tr>
#         <th>A</td>
#         <th>Index</td>
#         <th>C</td>
#         <th>B</td>
#     <tr>
#     <tr>
#       <td class='chart'>
#             <p>0</p>
#             <span class='index' style=' width: 100%; '></span>
#       </td>
#       <td class='chart'>
#             <p>1.0</p>
#             <span class='index' style=' width: 50%;  background: #f00;'></span>
#       </td>
#       <td class='chart'>
#             <p>gray</p>
#             <span class='index' style=' width: 100%;  background: #808080;'></span>
#       </td>
#       <td class='chart'>
#             <p>a</p>
#             <span class='index' style=' width: 100%;  background: #f00;'></span>
#       </td>
#     </tr>
#     <tr>
#       <td class='chart'>
#             <p>1</p>
#             <span class='index' style=' width: 100%; '></span>
#       </td>
#       <td class='chart'>
#             <p>2.0</p>
#             <span class='index' style=' width: 80%;  background: #008000;'></span>
#       </td>
#       <td class='chart'>
#             <p>gray</p>
#             <span class='index' style=' width: 100%;  background: #808080;'></span>
#       </td>
#       <td class='chart'>
#             <p>b</p>
#             <span class='index' style=' width: 100%;  background: #800000;'></span>
#       </td>
#     </tr>
#     <tr>
#       <td class='chart'>
#             <p>2</p>
#             <span class='index' style=' width: 100%; '></span>
#       </td>
#       <td class='chart'>
#             <p>3.0</p>
#             <span class='index' style=' width: 30%;  background: #00f;'></span>
#       </td>
#       <td class='chart'>
#             <p>blue</p>
#             <span class='index' style=' width: 100%;  background: #00f;'></span>
#       </td>
#       <td class='chart'>
#             <p>c</p>
#             <span class='index' style=' width: 100%;  background: #ff0;'></span>
#       </td>
#     </tr>
# </table>
